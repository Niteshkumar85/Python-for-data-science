# %% [markdown]
# ## Comments and Indentation
#
#  - Comments are the line that exist in computer programs that are ignored by compilers and interpreters.
#  - Including comments in programs makes code more readable for human as it provide some information or explaination about what each part or line of code is doing .
#  - In python we use ( # ) symbole for to writting a comments

# %%
# Prints Hello World in console
print("Hello World !")
# Out:
# Hello World !

# %% [markdown]
# # Multi line comments
#  - If we have to wirte more about the line of code in our code part that it help us to read or understand the concept behind that line
#  - we can use multiline comments ( ''' The statement which we have to write here

# %%
''' the code which we are writing here is uses
 this kind of information in code 
 if we have in our console to this we can write in our multiline comments section '''
# Out:
# ' the code which we are writing here is uses\n this kind of information in code \n if we have in our console to this we can write in our multiline comments section '

# %% [markdown]
# # Python Indentation
#
#  - Most of the progamming languages like c, c++ , java use braces {} to define a block of code and the python uses Identation.
#  - Generally four whitespaces are used for indentation and is preferred over tabs .

# %%
# for example 
for i in range(101):
    
    print("\n" , i , " / 2") # so here we have uses a indentation rather than the braces in other languages
    print("\n" , i/2)
# Out:
#  0  / 2
#
#  0.0
#
#  1  / 2
#
#  0.5
#
#  2  / 2
#
#  1.0
#
#  3  / 2
#
#  1.5
#
#  4  / 2
#
#  2.0
#
#  5  / 2
#
#  2.5
#
#  6  / 2
#
#  3.0
#
#  7  / 2
#
#  3.5
#
#  8  / 2
#
#  4.0
#
#  9  / 2
#
#  4.5
#
#  10  / 2
#
#  5.0
#
#  11  / 2
#
#  5.5
#
#  12  / 2
#
#  6.0
#
#  13  / 2
#
#  6.5
#
#  14  / 2
#
#  7.0
#
#  15  / 2
#
#  7.5
#
#  16  / 2
#
#  8.0
#
#  17  / 2
#
#  8.5
#
#  18  / 2
#
#  9.0
#
#  19  / 2
#
#  9.5
#
#  20  / 2
#
#  10.0
#
#  21  / 2
#
#  10.5
#
#  22  / 2
#
#  11.0
#
#  23  / 2
#
#  11.5
#
#  24  / 2
#
#  12.0
#
#  25  / 2
#
#  12.5
#
#  26  / 2
#
#  13.0
#
#  27  / 2
#
#  13.5
#
#  28  / 2
#
#  14.0
#
#  29  / 2
#
#  14.5
#
#  30  / 2
#
#  15.0
#
#  31  / 2
#
#  15.5
#
#  32  / 2
#
#  16.0
#
#  33  / 2
#
#  16.5
#
#  34  / 2
#
#  17.0
#
#  35  / 2
#
#  17.5
#
#  36  / 2
#
#  18.0
#
#  37  / 2
#
#  18.5
#
#  38  / 2
#
#  19.0
#
#  39  / 2
#
#  19.5
#
#  40  / 2
#
#  20.0
#
#  41  / 2
#
#  20.5
#
#  42  / 2
#
#  21.0
#
#  43  / 2
#
#  21.5
#
#  44  / 2
#
# ...
